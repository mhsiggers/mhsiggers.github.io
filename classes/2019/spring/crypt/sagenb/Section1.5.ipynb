# %% [markdown]
# <p><span style="font-size: large;">Section 1.5 &nbsp;Powers and Primitive Roots in Finite Fields</span></p>
#
#
# <p>Find the multiplicative order of the number 7 modulo 11</p>

# %%
M11 =Integers(11)

# %%
multiplicative_order(M11(7))
# Out:
# 10

# %% [markdown]
# <p>Get one of the generators of the of the multiplicative group. This is a primitive root of the field.</p>

# %%
M11.multiplicative_generator()
# Out:
# 2
