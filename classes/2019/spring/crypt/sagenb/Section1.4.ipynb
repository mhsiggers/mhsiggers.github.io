# %% [markdown]
# <p><span style="font-size: large;">Section 1.4 Primes, Unique Factorisation and Finite Fields</span>&nbsp;</p>
#
# <p>We want to work with big primes.  Here are some functions we will need.</p>

# %%
is_prime(651)

# %%
next_prime(651)

# %%
random_prime(10000)

# %%
factor(3615557496)
