# %% [markdown]
# To make programs we will have to do conditions and loops.  Here are a couple of typical examples.

# %%
for i in range(6):
   print i
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
count=1
while count < 7 :
    print count
    count = count + 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
count=1
while count < 10 :
    if count.is_square():
      print count
    count = count + 1
# Out:
# 1
# 4
# 9

# %% [markdown]
#  ## Important:
#
#   The proper indentation is important when you define a function.

# %%
for i in range(20):
    n = i+1;
    if n.is_prime(): 
        print n, "is prime"
    else: 
        print n, "is composite"
# Out:
# 1 is composite
# 2 is prime
# 3 is prime
# 4 is composite
# 5 is prime
# 6 is composite
# 7 is prime
# 8 is composite
# 9 is composite
# 10 is composite
# 11 is prime
# 12 is composite
# 13 is prime
# 14 is composite
# 15 is composite
# 16 is composite
# 17 is prime
# 18 is composite
# 19 is prime
# 20 is composite

# %% [markdown]
# <p><span style="font-size: large;">Section 1.2 &nbsp;Divisibility and GCDs.</span></p>
#
# <p>Sage can quickly decide for us if a number divides another, or find the GCD of two numbers. </p>

# %%
3.divides(12), 3.divides(10)
# Out:
# (True, False)

# %%
a = 3

# %%
a.prime_factors()
# Out:
# [3]

# %%
gcd(10,4)
# Out:
# 2

# %% [markdown]
# <p>We can even do the Extended Euclidean Algorithm to compute the coefficients u and v of a and b in representing the g = gcd(a,b).</p>

# %%
g,u,v = xgcd(10,4); g; u; v
# Out:
# -2

# %% [markdown]
# <p> Test that it is correct. </p>

# %%
g == u*10 +v*4
# Out:
# True

# %% [markdown]
# <p>It can even do this in more general rings.</p>

# %%
P.<x> = PolynomialRing(ZZ)

# %%
(x+1).divides(x^2 - 1)
# Out:
# True

# %% [markdown]
# <p>But lets just play with integers for now. Some more useful functions are. </p>

# %%
factor(376824)
# Out:
# 2^3 * 3 * 7 * 2243

# %%
divisors(376824)
# Out:
# [1,
#  2,
#  3,
#  4,
#  6,
#  7,
#  8,
#  12,
#  14,
#  21,
#  24,
#  28,
#  42,
#  56,
#  84,
#  168,
#  2243,
#  4486,
#  6729,
#  8972,
#  13458,
#  15701,
#  17944,
#  26916,
#  31402,
#  47103,
#  53832,
#  62804,
#  94206,
#  125608,
#  188412,
#  376824]

# %%
def myDivide(A,B):
    q = 0
    r = A
    while r > B :
        q = q + 1;
        r = r - B;
    return(q,r)

# %%
myDivide(27,4)
# Out:
# (6, 3)
